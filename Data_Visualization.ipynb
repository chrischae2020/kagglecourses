# %% [markdown]
# # Hello seaborn

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # line Charts

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
museum_filepath = "data/museum_visitors.csv"

# Fill in the line below to read the file into a variable museum_data
museum_data = pd.read_csv(museum_filepath, index_col="Month",parse_dates=True)
 
museum_data.head()
# Out:
#             America Tropical Interpretive Center  Avila Adobe  \
# Month
# 2014-01-01                                  6602        24778
# 2014-02-01                                  5029        18976
# 2014-03-01                                  8129        25231
# 2014-04-01                                  2824        26989
# 2014-05-01                                 10694        36883
#
#             Chinese American Museum  Gateway to Nature Center  \
# Month
# 2014-01-01                     1581                       NaN
# 2014-02-01                     1785                       NaN
# 2014-03-01                     3229                       NaN
# 2014-04-01                     2129                       NaN
# 2014-05-01                     3676                       NaN
#
#             Firehouse Museum  Hellman Quon  IAMLA  Pico House   \
# Month
# 2014-01-01              4486           0.0    NaN       2204.0
# 2014-02-01              4172           0.0    NaN       1330.0
# 2014-03-01              7082          70.0    NaN       4320.0
# 2014-04-01              6756         250.0    NaN       3277.0
# 2014-05-01             10858         135.0    NaN       4122.0
#
#             Visitor Center/ El Tranquilo Gallery  Museum of Social Justice  \
# Month
# 2014-01-01                                2961.0                       NaN
# 2014-02-01                                2276.0                       NaN
# 2014-03-01                                3116.0                       NaN
# 2014-04-01                                2808.0                       NaN
# 2014-05-01                                3987.0                       NaN
#
#             Biscailuz Gallery
# Month
# 2014-01-01                NaN
# 2014-02-01                NaN
# 2014-03-01                NaN
# 2014-04-01                NaN
# 2014-05-01                NaN

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=museum_data)
plt.title("Monthly Visitors to Los Angeles City Museums")

# Check your answer
step_3.check()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-431ad3ae07a1> in <module>
#       2
#       3 plt.figure(figsize=(12, 6))
# ----> 4 sns.lineplot(data=museum_data)
#       5 plt.title("Monthly Visitors to Los Angeles City Museums")
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1129         dashes=dashes, markers=markers, style_order=style_order,
#    1130         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1131         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1132     )
#    1133
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     707         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     708         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
# --> 709         self.parse_style(plot_data["style"], markers, dashes, style_order)
#     710
#     711         self.units = units
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in parse_style(self, data, markers, dashes, order)
#     525
#     526             dashes = self.style_to_attributes(
# --> 527                 levels, dashes, self.default_dashes, "dashes"
#     528             )
#     529
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in style_to_attributes(self, levels, style, defaults, name)
#     307             if any(missing_levels):
#     308                 err = "These `style` levels are missing {}: {}"
# --> 309                 raise ValueError(err.format(name, missing_levels))
#     310
#     311         return attrdict
#
# ValueError: These `style` levels are missing dashes: {'Museum of Social Justice', 'Visitor Center/ El Tranquilo Gallery', 'Biscailuz Gallery', 'Pico House ', 'IAMLA'}

# %% [markdown]
# # scatterplots

# %%
# Path of the file to read
insurance_filepath = "data/insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
